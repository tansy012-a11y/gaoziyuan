# %% [markdown]
# ## 插入序列：[30, 20, 10, 25, 40, 35, 50]
#
# ### 1. 插入 30
# ```
# 30(0)
# ```
#
# ### 2. 插入 20
# ```
# 30(1)
# /
# 20(0)
# ```
#
# ### 3. 插入 10 → 失衡 (LL，右旋30)
# ```
#   20(0)
#  /    \
# 10(0) 30(0)
# ```
#
# ### 4. 插入 25
# ```
#   20(-1)
#  /    \
# 10(0) 30(1)
#      /
#    25(0)
# ```
#
# ### 5. 插入 40
# ```
#   20(-1)
#  /    \
# 10(0) 30(0)
#      /  \
#    25(0)40(0)
# ```
#
# ### 6. 插入 35 → 失衡 (RL，先右旋40，再左旋20)
# ```
#      30(0)
#     /    \
#   20(0)  35(-1)
#  /   \      \
# 10(0)25(0)  40(0)
# ```
#
# ### 7. 插入 50 → 失衡 (RR，左旋35)
# ```
#      30(0)
#     /    \
#   20(0)  40(0)
#  /   \   /  \
# 10(0)25(0)35(0)50(0)
# ```
#
# **最终树**：
# ```
#       30
#      /  \
#     20   40
#    / \   / \
#   10 25 35 50
# ```
# **中序遍历**：10,20,25,30,35,40,50 ✅
